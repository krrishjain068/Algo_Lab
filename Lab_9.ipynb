# %% [markdown]
# <a href="https://colab.research.google.com/github/krrishjain068/Algo_Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous


def shortest_path(previous, start, target):
    path = []
    node = target
    while node is not None:
        path.insert(0, node)
        node = previous[node]
    return path if path[0] == start else []

# %%
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}

m = int(input("Enter number of edges: "))
for i in range(m):
    u, v, w = input(f"Enter edge {i+1} (format: U V W): ").split()
    w = int(w)
    graph[u][v] = w
    graph[v][u] = w
start = input("Enter source node: ")
distances, previous = dijkstra(graph, start)

print("\nShortest paths from", start)
for node in graph:
    path = shortest_path(previous, start, node)
    print(f"{start} → {node}: Path = {path}, Distance = {distances[node]}")
# Out:
# Enter number of nodes: 4
# Enter node 1 name: A
# Enter node 2 name: B
# Enter node 3 name: C
# Enter node 4 name: D
# Enter number of edges: 10
# Enter edge 1 (format: U V W): A B 4
# Enter edge 2 (format: U V W): A D 7
# Enter edge 3 (format: U V W): B C 9
# Enter edge 4 (format: U V W): B D 11
# Enter edge 5 (format: U V W): B A  6
# Enter edge 6 (format: U V W): C A 3
# Enter edge 7 (format: U V W): C B 12
# Enter edge 8 (format: U V W): C D 4
# Enter edge 9 (format: U V W): D B 13
# Enter edge 10 (format: U V W): D C 10
# Enter source node: A
#
# Shortest paths from A
# A → A: Path = ['A'], Distance = 0
# A → B: Path = ['A', 'B'], Distance = 6
# A → C: Path = ['A', 'C'], Distance = 3
# A → D: Path = ['A', 'D'], Distance = 7

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
